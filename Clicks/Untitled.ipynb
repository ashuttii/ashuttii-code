# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
data = pd.read_csv(r'phppCF8Zy.csv')
data.head()
# Out:
#    click  impression      url_hash     ad_id  advertiser_id  depth  position  \
# 0      0           3  6.324021e+18  20711339          27500      2         2
# 1      0           1  1.434039e+19  10398727          23808      2         2
# 2      0           1  3.730625e+17   3827183          23792      1         1
# 3      0           2  7.214093e+17   4427867          28622      1         1
# 4      0           2  1.628772e+19   1983809          11810      3         2
#
#    query_id  keyword_id  title_id  description_id  user_id
# 0       135        2846     12631           26225  1887952
# 1  10123638       14133     19101           18378  7665680
# 2      3307        5348        61              77    66280
# 3     62262       62466    127249          170983        0
# 4   8560016        8139     37594            2339      290

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1496391 entries, 0 to 1496390
# Data columns (total 12 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   click           1496391 non-null  int64
#  1   impression      1496391 non-null  int64
#  2   url_hash        1496391 non-null  float64
#  3   ad_id           1496391 non-null  int64
#  4   advertiser_id   1496391 non-null  int64
#  5   depth           1496391 non-null  int64
#  6   position        1496391 non-null  int64
#  7   query_id        1496391 non-null  int64
#  8   keyword_id      1496391 non-null  int64
#  9   title_id        1496391 non-null  int64
#  10  description_id  1496391 non-null  int64
#  11  user_id         1496391 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 137.0 MB

# %%
for col in data:
    print(col , data[col].nunique())
# Out:
# click 2
# impression 389
# url_hash 19727
# ad_id 159955
# advertiser_id 13646
# depth 3
# position 3
# query_id 822185
# keyword_id 196000
# title_id 386492
# description_id 315255
# user_id 976977

# %%
data['position'].unique()
# Out:
# array([2, 1, 3])

# %%
data.corr()
# Out:
#                    click  impression  url_hash     ad_id  advertiser_id  \
# click           1.000000    0.012725 -0.004730 -0.002585      -0.011950
# impression      0.012725    1.000000  0.000332 -0.000149       0.000424
# url_hash       -0.004730    0.000332  1.000000 -0.021231       0.083518
# ad_id          -0.002585   -0.000149 -0.021231  1.000000       0.336593
# advertiser_id  -0.011950    0.000424  0.083518  0.336593       1.000000
# depth          -0.030617   -0.000848 -0.044903  0.043948       0.030374
# position       -0.067052   -0.000447 -0.031804  0.034714       0.021198
# query_id       -0.040514   -0.003587  0.006908 -0.031667      -0.050399
# keyword_id      0.017240   -0.000793 -0.025996  0.002902      -0.057460
# title_id        0.007624   -0.001045 -0.038830  0.045917      -0.005362
# description_id  0.003838   -0.001009 -0.039519  0.031181      -0.009019
# user_id         0.038637   -0.004446  0.032640 -0.004503       0.024271
#
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
plt.plot(corr_mushrooms['cap-shape'], norm.pdf(corr_mushrooms['cap-shape'], corr_mushrooms['cap-shape'].mean(), corr_mushrooms['cap-shape'].std()))
plt.show()

# %%
mush_col = corr_mushrooms.columns
for col in corr_mushrooms:
    corr_mushrooms[col] = corr_mushrooms[col].astype(str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4ba81632b59c> in <module>
# ----> 1 mush_col = corr_mushrooms.columns
#       2 for col in corr_mushrooms:
#       3     corr_mushrooms[col] = corr_mushrooms[col].astype(int)
#       4
#
# NameError: name 'corr_mushrooms' is not defined

# %%
data1 = data.copy()

# %%
data_col = data1.columns
for col in data_col:
    data1[col] = data1[col].astype(str)

# %%
data1.dtypes
# Out:
# click             object
# impression        object
# url_hash          object
# ad_id             object
# advertiser_id     object
# depth             object
# position          object
# query_id          object
# keyword_id        object
# title_id          object
# description_id    object
# user_id           object
# dtype: object
